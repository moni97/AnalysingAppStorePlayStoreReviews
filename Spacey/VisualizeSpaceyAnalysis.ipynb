# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import numpy as np
import json
import csv
from app_store_scraper import AppStore
from tqdm import tqdm
import os.path
import ast
import matplotlib.pyplot as plt

# %%
analysisDF = pd.read_csv("Analysis.csv")

# %%
analysisDF.head(10)
# Out:
#                  App           Category  \
# 0           Lumosity        Educational
# 1           Lumosity        Educational
# 2           Lumosity        Educational
# 3      Spaces by Wix  Productivity Apps
# 4      Spaces by Wix  Productivity Apps
# 5      Spaces by Wix  Productivity Apps
# 6      Spaces by Wix  Productivity Apps
# 7      Spaces by Wix  Productivity Apps
# 8      Spaces by Wix  Productivity Apps
# 9  LinkedIn Learning        Educational
#
#                                     App Store Review  \
# 0  I don’t mind paying for the premium subscripti...
# 1  I enjoyed the routine of playing Lumosity game...
# 2  Please please please please! Release train of ...
# 3  If you read all these reviews....well I’m sorr...
# 4  Starting your own business is never easy. That...
# 5  I've seen and used other quick start websites ...
# 6  I’m starting my own auto detailing company and...
# 7  I really like how easy it is for me to manage ...
# 8  I really like using it for my personal trainin...
# 9  Love the training material, but am I missing s...
#
#                                    Play Store Review    Feature  \
# 0  It was really good for your brain excerise (in...    premium
# 1  This app is awesome but premium is expensive $...    premium
# 2  This app is awesome but premium is expensive $...    premium
# 3  If you want to create an app for your business...       easy
# 4  If you want to create an app for your business...       easy
# 5  If you want to create an app for your business...       easy
# 6  Very solidified app along with a profitable an...     simple
# 7  If you want to create an app for your business...       easy
# 8  If you want to create an app for your business...       easy
# 9  video download speed poor, should default to l...  landscape
#
#                     label                               Sentiment Scores IOS  \
# 0  NON-TECHNICAL/BUSINESS  {'neg': 0.034, 'neu': 0.82, 'pos': 0.146, 'com...
# 1  NON-TECHNICAL/BUSINESS  {'neg': 0.051, 'neu': 0.74, 'pos': 0.209, 'com...
# 2  NON-TECHNICAL/BUSINESS  {'neg': 0.045, 'neu': 0.684, 'pos': 0.271, 'co...
# 3              EFFICIENCY  {'neg': 0.072, 'neu': 0.736, 'pos': 0.192, 'co...
# 4              EFFICIENCY  {'neg': 0.054, 'neu': 0.756, 'pos': 0.19, 'com...
# 5              EFFICIENCY  {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'comp...
# 6              EFFICIENCY  {'neg': 0.048, 'neu': 0.917, 'pos': 0.035, 'co...
# 7              EFFICIENCY  {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'comp...
# 8              EFFICIENCY  {'neg': 0.076, 'neu': 0.617, 'pos': 0.307, 'co...
# 9                      UI  {'neg': 0.039, 'neu': 0.814, 'pos': 0.147, 'co...
#
#                              Sentiment Score Android
# 0  {'neg': 0.133, 'neu': 0.73, 'pos': 0.137, 'com...
# 1  {'neg': 0.0, 'neu': 0.836, 'pos': 0.164, 'comp...
# 2  {'neg': 0.0, 'neu': 0.836, 'pos': 0.164, 'comp...
# 3  {'neg': 0.0, 'neu': 0.815, 'pos': 0.185, 'comp...
# 4  {'neg': 0.0, 'neu': 0.815, 'pos': 0.185, 'comp...
# 5  {'neg': 0.0, 'neu': 0.815, 'pos': 0.185, 'comp...
# 6  {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'comp...
# 7  {'neg': 0.0, 'neu': 0.815, 'pos': 0.185, 'comp...
# 8  {'neg': 0.0, 'neu': 0.815, 'pos': 0.185, 'comp...
# 9  {'neg': 0.171, 'neu': 0.829, 'pos': 0.0, 'comp...

# %%
appNames = analysisDF["App"].unique()

# %%
def getReviewAverage(reviewScoreArray):
    avgRes = {"neg": 0, "pos": 0, "neu": 0, "compound": 0}
    negSum = neuSum = posSum = cpdSum = 0
    for review in reviewScoreArray:
        reviewDict = ast.literal_eval(review)
        negSum += reviewDict['neg']
        neuSum += reviewDict['neu']
        posSum += reviewDict['pos']
        cpdSum += reviewDict['compound']
    avgRes["neg"] = negSum / len(reviewScoreArray)
    avgRes["neu"] = neuSum / len(reviewScoreArray)     
    avgRes["pos"] = posSum / len(reviewScoreArray)     
    avgRes["compound"] = cpdSum / len(reviewScoreArray)
    return avgRes

# %%
resultDF = pd.DataFrame()

# %%
for app in appNames:
    individualAppDF = analysisDF[analysisDF["App"] == app]
    iosSentimentScores = individualAppDF["Sentiment Scores IOS"]
    androidSentimentScores = individualAppDF["Sentiment Score Android"]
    iosReviewAverage = getReviewAverage(iosSentimentScores)
    androidReviewAverage = getReviewAverage(androidSentimentScores)
    labelSum = individualAppDF["label"].unique()
    dictToAdd = {
        "App": app,
        "Category": ",".join(individualAppDF["Category"].unique()),
        "label": ",".join(labelSum),
        "Feature": ",".join(individualAppDF["Feature"].unique()),
        "IOS Neg Score": iosReviewAverage["neg"],
        "Android Neg Score": androidReviewAverage["neg"],
        "IOS Pos Score": iosReviewAverage["pos"],
        "Android Pos Score": androidReviewAverage["pos"],
        "IOS Neu Score": iosReviewAverage["neu"],
        "Android Neu Score": androidReviewAverage["neu"],
        "IOS Compound Score": iosReviewAverage["compound"],
        "Android Compound Score": androidReviewAverage["compound"]
    }
    resultDF = pd.concat([resultDF, pd.DataFrame.from_records([dictToAdd])], ignore_index=True)

# %%
resultDF
# Out:
#                                App                       Category  \
# 0                         Lumosity                    Educational
# 1                    Spaces by Wix              Productivity Apps
# 2                LinkedIn Learning                    Educational
# 3                        Wordpress              Productivity Apps
# 4                     Healthify Me             Health and Fitness
# 5                           Notion              Productivity Apps
# 6                         Fox News  News/ Information Outlet Apps
# 7    DataCamp : Learn Data Science                    Educational
# 8                 Six pack promise             Health and Fitness
# 9     Merriam - Webster Dictionary                    Educational
# 10                            Zara                 Lifestyle Apps
# 11            Booksy for Customers                 Lifestyle Apps
# 12   Yoga-Go: Yoga for weight loss             Health and Fitness
# 13   Forever 21-The Latest Fashion                 Lifestyle Apps
# 14                        DocuSign              Productivity Apps
# 15               Otter Voice Notes              Productivity Apps
# 16  Viber Messenger: Chats & Calls              Social Media Apps
# 17  BodyFast: Intermittent Fasting             Health and Fitness
# 18                       SoloLearn                    Educational
# 19                        Coursera                    Educational
# 20                  Xbox game pass             Entertainment Apps
# 21                             EdX                    Educational
# 22             StepsApp Predometer             Health and Fitness
# 23    Trulia Real Estate & Rentals                 Lifestyle Apps
# 24                   MS Whiteboard              Productivity Apps
# 25                      Adobe Scan              Productivity Apps
# 26                        Jamboard              Productivity Apps
# 27               Oxford Dictionary                    Educational
# 28   Nike: Shoes, Apparel, Stories                 Lifestyle Apps
# 29                       Clubhouse             Entertainment Apps
# 30                  Zillow Rentals                 Lifestyle Apps
# 31                       Splitwise       Banking & Financial Apps
# 32                         Dropbox              Productivity Apps
# 33                       Flipboard  News/ Information Outlet Apps
# 34  Workout Planner muscle booster             Health and Fitness
# 35                    Club Pilates             Health and Fitness
# 36                     Proton mail              Productivity Apps
# 37                           Udemy                    Educational
# 38                          G Keep              Productivity Apps
# 39                         Post-it              Productivity Apps
#
#                                                 label  \
# 0                              NON-TECHNICAL/BUSINESS
# 1                                          EFFICIENCY
# 2               UI,EFFICIENCY,GRAPHICS,RESPONSIVENESS
# 3                                          EFFICIENCY
# 4                                          EFFICIENCY
# 5                   EFFICIENCY,CRASHES,RESPONSIVENESS
# 6                                             CRASHES
# 7                                          EFFICIENCY
# 8   CRASHES,EFFICIENCY,NON-TECHNICAL/BUSINESS,RESP...
# 9                   EFFICIENCY,NON-TECHNICAL/BUSINESS
# 10                                 EFFICIENCY,CRASHES
# 11   EFFICIENCY,RESPONSIVENESS,NON-TECHNICAL/BUSINESS
# 12                                         EFFICIENCY
# 13                                            CRASHES
# 14                                         EFFICIENCY
# 15                                         EFFICIENCY
# 16                             CRASHES,RESPONSIVENESS
# 17                  NON-TECHNICAL/BUSINESS,EFFICIENCY
# 18                          RESPONSIVENESS,EFFICIENCY
# 19                                            CRASHES
# 20          CRASHES,NON-TECHNICAL/BUSINESS,EFFICIENCY
# 21                                 CRASHES,EFFICIENCY
# 22                             NON-TECHNICAL/BUSINESS
# 23                                         EFFICIENCY
# 24  CRASHES,GRAPHICS,UI,EFFICIENCY,WIDGETS,RESPONS...
# 25                                         EFFICIENCY
# 26       CRASHES,RESPONSIVENESS,EFFICIENCY,WIDGETS,UI
# 27                             NON-TECHNICAL/BUSINESS
# 28                                            CRASHES
# 29                                         UI,CRASHES
# 30                              UI,EFFICIENCY,CRASHES
# 31                                         EFFICIENCY
# 32                                     RESPONSIVENESS
# 33                     NON-TECHNICAL/BUSINESS,CRASHES
# 34                                         EFFICIENCY
# 35          EFFICIENCY,NON-TECHNICAL/BUSINESS,CRASHES
# 36                    NON-TECHNICAL/BUSINESS,GRAPHICS
# 37                                            CRASHES
# 38  CRASHES,WIDGETS,EFFICIENCY,UI,NON-TECHNICAL/BU...
# 39       EFFICIENCY,UI,WIDGETS,NON-TECHNICAL/BUSINESS
#
#                                               Feature  IOS Neg Score  \
# 0                                             premium       0.043333
# 1                                         easy,simple       0.041667
# 2                              landscape,UI,easy,slow       0.063429
# 3                                    Easy,easy,simple       0.038786
# 4                                   complex,confusing       0.191500
# 5   simple,improvements,excellent,buggy,difficult,...       0.036111
# 6                                                 bug       0.070000
# 7                  intuitive,easy,simple,smooth,clean       0.012217
# 8    freezes,simple,reminders,great workouts,annoying       0.041875
# 9                                 easy,amazing,smooth       0.008857
# 10                                    easy,error,slow       0.063500
# 11                        convenient,great,easy,clean       0.034727
# 12                                               easy       0.000000
# 13                                           glitches       0.039000
# 14                 easy,convenient,Easy,simple,easier       0.027677
# 15                           accurate,accuracy,simple       0.026818
# 16                                      crashing,slow       0.032000
# 17               premium,reminders,easy,Easy,reminder       0.032429
# 18                                       great,simple       0.142500
# 19                                            crashes       0.000000
# 20                        laggy,crashes,best,smoother       0.106000
# 21                               freezes,great,simple       0.074667
# 22                                              track       0.022250
# 23                                        easy,useful       0.030000
# 24  lag,refresh,color,unstable,easy,whiteboard,slo...       0.092462
# 25                                        easy,simple       0.007333
# 26  bugs,crash,slow,glitches,laggy,hard,jamboard,c...       0.091316
# 27                                            premium       0.042000
# 28                                            freezes       0.098000
# 29                                       icon,crashes       0.040500
# 30                        filter,easier,filters,error       0.054500
# 31                   intuitive,convenient,easy,simple       0.041167
# 32                                      automatically       0.117000
# 33                                informative,crashes       0.032500
# 34                                            amazing       0.075000
# 35               convenient,calendar,error,clean,bugs       0.056833
# 36                                   secure,dark mode       0.063000
# 37                                          Unable to       0.086000
# 38  crashes,widget,organized,font,highlighted,cras...       0.052429
# 39  SIMPLE,widget,intuitive,organized,simple,Easy,...       0.016538
#
#     Android Neg Score  IOS Pos Score  Android Pos Score  IOS Neu Score  \
# 0            0.044333       0.208667           0.155000       0.748000
# 1            0.000000       0.200500           0.194833       0.757833
# 2            0.151571       0.169571           0.131714       0.767143
# 3            0.037429       0.224000           0.202286       0.737143
# 4            0.063000       0.028000           0.073000       0.780500
# 5            0.109889       0.209889           0.145000       0.753889
# 6            0.000000       0.125000           0.000000       0.805000
# 7            0.103217       0.290304           0.106217       0.697478
# 8            0.117875       0.153625           0.160125       0.804625
# 9            0.022286       0.230286           0.169429       0.760857
# 10           0.068500       0.224750           0.107750       0.711750
# 11           0.071273       0.213091           0.220182       0.752273
# 12           0.014000       0.249714           0.154571       0.750286
# 13           0.000000       0.199000           0.000000       0.762000
# 14           0.083194       0.221387           0.212548       0.750935
# 15           0.041818       0.138182           0.100818       0.835091
# 16           0.083333       0.225333           0.000000       0.742667
# 17           0.083857       0.253571           0.175143       0.713905
# 18           0.000000       0.081000           0.317000       0.777500
# 19           0.112000       0.128000           0.121000       0.872000
# 20           0.000000       0.129000           0.242250       0.765000
# 21           0.145333       0.250000           0.143333       0.675333
# 22           0.241000       0.196500           0.216000       0.781250
# 23           0.117500       0.197333           0.171167       0.772833
# 24           0.131308       0.130231           0.185000       0.777308
# 25           0.037000       0.239667           0.158000       0.753000
# 26           0.076158       0.094474           0.130421       0.814158
# 27           0.117000       0.204000           0.101000       0.754000
# 28           0.000000       0.000000           0.284000       0.902000
# 29           0.083500       0.258500           0.000000       0.701000
# 30           0.126000       0.154833           0.101667       0.790833
# 31           0.025333       0.233333           0.234167       0.725611
# 32           0.106000       0.174000           0.121000       0.709000
# 33           0.000000       0.191000           0.162500       0.777000
# 34           0.000000       0.069000           0.590000       0.856000
# 35           0.129000       0.175333           0.170833       0.767833
# 36           0.083000       0.173500           0.320500       0.763000
# 37           0.154000       0.205000           0.000000       0.709000
# 38           0.104714       0.172286           0.104857       0.775286
# 39           0.084385       0.239692           0.175154       0.743769
#
#     Android Neu Score  IOS Compound Score  Android Compound Score
# 0            0.800667            0.888500                0.255733
# 1            0.805167            0.756583                0.356733
# 2            0.716857            0.586229               -0.121114
# 3            0.760214            0.781886                0.290536
# 4            0.864000           -0.586000                0.038600
# 5            0.745111            0.698678                0.061022
# 6            1.000000            0.653100                0.000000
# 7            0.790565            0.766696               -0.023730
# 8            0.722000            0.545650                0.210575
# 9            0.808286            0.949671                0.304814
# 10           0.823750            0.512000                0.084925
# 11           0.708545            0.750364                0.368518
# 12           0.831429            0.863271                0.207857
# 13           1.000000            0.877000                0.000000
# 14           0.703677            0.793848                0.323881
# 15           0.857182            0.715327                0.108891
# 16           0.916667            0.873067               -0.152533
# 17           0.741000            0.791362                0.241771
# 18           0.683000           -0.373400                0.665250
# 19           0.767000            0.895500                0.038700
# 20           0.757750           -0.167375                0.514300
# 21           0.711333            0.456933                0.152533
# 22           0.542000            0.908450                0.126300
# 23           0.711333            0.696500                0.050800
# 24           0.683385            0.034238                0.166915
# 25           0.805000            0.954167                0.324767
# 26           0.793526            0.055700                0.111442
# 27           0.781000            0.827100               -0.052600
# 28           0.716000           -0.695600                0.713300
# 29           0.916500            0.943600               -0.148000
# 30           0.772333            0.362750               -0.043517
# 31           0.740500            0.740556                0.389056
# 32           0.773000            0.726000                0.077200
# 33           0.837500            0.896000                0.305600
# 34           0.410000           -0.113400                0.877200
# 35           0.700167            0.524700                0.001133
# 36           0.596500            0.616500                0.236350
# 37           0.846000            0.881300               -0.292400
# 38           0.790429            0.623300                0.006771
# 39           0.740462            0.460515                0.219646

# %%
resultDF.to_csv("AggregatedResult.csv", mode="a", index=False, header=True)

# %%
categories = resultDF['Category'].unique()

# %%
categories
# Out:
# array(['Educational', 'Productivity Apps', 'Health and Fitness',
#        'News/ Information Outlet Apps', 'Lifestyle Apps',
#        'Social Media Apps', 'Entertainment Apps',
#        'Banking & Financial Apps'], dtype=object)

# %%
resultDF[resultDF['Category'] == categories[2]]
# Out:
#                                App            Category  \
# 4                     Healthify Me  Health and Fitness
# 8                 Six pack promise  Health and Fitness
# 12   Yoga-Go: Yoga for weight loss  Health and Fitness
# 17  BodyFast: Intermittent Fasting  Health and Fitness
# 22             StepsApp Predometer  Health and Fitness
# 34  Workout Planner muscle booster  Health and Fitness
# 35                    Club Pilates  Health and Fitness
#
#                                                 label  \
# 4                                          EFFICIENCY
# 8   CRASHES,EFFICIENCY,NON-TECHNICAL/BUSINESS,RESP...
# 12                                         EFFICIENCY
# 17                  NON-TECHNICAL/BUSINESS,EFFICIENCY
# 22                             NON-TECHNICAL/BUSINESS
# 34                                         EFFICIENCY
# 35          EFFICIENCY,NON-TECHNICAL/BUSINESS,CRASHES
#
#                                              Feature  IOS Neg Score  \
# 4                                  complex,confusing       0.191500
# 8   freezes,simple,reminders,great workouts,annoying       0.041875
# 12                                              easy       0.000000
# 17              premium,reminders,easy,Easy,reminder       0.032429
# 22                                             track       0.022250
# 34                                           amazing       0.075000
# 35              convenient,calendar,error,clean,bugs       0.056833
#
#     Android Neg Score  IOS Pos Score  Android Pos Score  IOS Neu Score  \
# 4            0.063000       0.028000           0.073000       0.780500
# 8            0.117875       0.153625           0.160125       0.804625
# 12           0.014000       0.249714           0.154571       0.750286
# 17           0.083857       0.253571           0.175143       0.713905
# 22           0.241000       0.196500           0.216000       0.781250
# 34           0.000000       0.069000           0.590000       0.856000
# 35           0.129000       0.175333           0.170833       0.767833
#
#     Android Neu Score  IOS Compound Score  Android Compound Score
# 4            0.864000           -0.586000                0.038600
# 8            0.722000            0.545650                0.210575
# 12           0.831429            0.863271                0.207857
# 17           0.741000            0.791362                0.241771
# 22           0.542000            0.908450                0.126300
# 34           0.410000           -0.113400                0.877200
# 35           0.700167            0.524700                0.001133

# %%
categoryDF = resultDF[resultDF['Category'] == categories[2]]
# Computing negative sentiment score
barWidth = 0.25
fig = plt.subplots(figsize =(20, 10))

X = categoryDF["App"].to_numpy()
X_axis = np.arange(len(X))


plt.bar(X_axis - 0.2, categoryDF["IOS Neg Score"].to_numpy(), 0.4, label = 'IOS')
plt.bar(X_axis + 0.2, categoryDF["Android Neg Score"].to_numpy(), 0.4, label = 'Android')

br1 = np.arange(len(appNames))
br2 = [x + barWidth for x in br1]

plt.ylim(0, 0.5)
plt.xticks(X_axis, X)
plt.xlabel(categories[1])
plt.ylabel("Negative Sentiment Score")
plt.title("Negative Sentiment score of each app")
plt.legend()
plt.savefig("NegativeSentimentScore.png")
plt.show()

# %%
categoryDF.loc[categoryDF.App.isin(['MS Whiteboard','Jamboard','Dropbox','Proton mail'])].to_csv("negPos.csv")

# %%
categoryDF = resultDF[resultDF['Category'] == categories[2]]
# Computing positive sentiment score
barWidth = 0.25
fig = plt.subplots(figsize =(20, 10))

X = categoryDF["App"].to_numpy()
X_axis = np.arange(len(X))


plt.bar(X_axis - 0.2, categoryDF["IOS Pos Score"].to_numpy(), 0.4, label = 'IOS')
plt.bar(X_axis + 0.2, categoryDF["Android Pos Score"].to_numpy(), 0.4, label = 'Android')

br1 = np.arange(len(appNames))
br2 = [x + barWidth for x in br1]

plt.xticks(X_axis, X)
plt.xlabel(categories[1])
plt.ylabel("Positive Sentiment Score")
plt.title("Positive Sentiment score of each app")
plt.legend()
plt.savefig("PositiveSentimentScore.png")
plt.show()

# %%
categoryDF.head()
# Out:
#                                App            Category  \
# 4                     Healthify Me  Health and Fitness
# 8                 Six pack promise  Health and Fitness
# 12   Yoga-Go: Yoga for weight loss  Health and Fitness
# 17  BodyFast: Intermittent Fasting  Health and Fitness
# 22             StepsApp Predometer  Health and Fitness
#
#                                                 label  \
# 4                                          EFFICIENCY
# 8   CRASHES,EFFICIENCY,NON-TECHNICAL/BUSINESS,RESP...
# 12                                         EFFICIENCY
# 17                  NON-TECHNICAL/BUSINESS,EFFICIENCY
# 22                             NON-TECHNICAL/BUSINESS
#
#                                              Feature  IOS Neg Score  \
# 4                                  complex,confusing       0.191500
# 8   freezes,simple,reminders,great workouts,annoying       0.041875
# 12                                              easy       0.000000
# 17              premium,reminders,easy,Easy,reminder       0.032429
# 22                                             track       0.022250
#
#     Android Neg Score  IOS Pos Score  Android Pos Score  IOS Neu Score  \
# 4            0.063000       0.028000           0.073000       0.780500
# 8            0.117875       0.153625           0.160125       0.804625
# 12           0.014000       0.249714           0.154571       0.750286
# 17           0.083857       0.253571           0.175143       0.713905
# 22           0.241000       0.196500           0.216000       0.781250
#
#     Android Neu Score  IOS Compound Score  Android Compound Score
# 4            0.864000           -0.586000                0.038600
# 8            0.722000            0.545650                0.210575
# 12           0.831429            0.863271                0.207857
# 17           0.741000            0.791362                0.241771
# 22           0.542000            0.908450                0.126300

# %%
playStoreFeatures = pd.read_csv("PlayStoreResults.csv")

# %%
appStoreFeatures = pd.read_csv("AppStoreResults.csv")

# %%
set(appStoreFeatures[appStoreFeatures['App'] == "MS Whiteboard"]['features'])
# Out:
# {'Easy', 'bugs|glitches', 'crash', nan, 'zoom'}

# %%
set(playStoreFeatures[playStoreFeatures['App'] == "MS Whiteboard"]['features'])
# Out:
# {'Crashes|placement',
#  'High -|super cool and boost my productivity to the next level 🙏💛💖',
#  'Smooth|whiteboard',
#  'Super|laggy',
#  'Unable to',
#  'amazing',
#  'awesome',
#  'best',
#  'black color|hard to',
#  'blue|color',
#  'colors',
#  'colors|color',
#  'color|color',
#  'complex',
#  'digital white',
#  'drawing',
#  'easy',
#  'eraser',
#  'expanding|whiteboard',
#  'fill',
#  'flawless',
#  'flexible',
#  'french',
#  'glitches',
#  'infinite',
#  'integration',
#  'lack features',
#  'lag',
#  'lag in',
#  'limitations',
#  'loading',
#  'log in|whiteboard',
#  nan,
#  'new',
#  'refresh',
#  'scrolling',
#  'simple|complicated',
#  'slow',
#  'slow|web view',
#  'small',
#  'syncing',
#  'syncs',
#  'sync|laggy',
#  'undo',
#  'unstable|heavy|smoothing',
#  'useful|handy',
#  'whiteboard',
#  'whiteboards',
#  'zoom'}

# %%
healthDF = resultDF[resultDF['Category'] == categories[2]]

# %%
healthDF
# Out:
#                                App            Category  \
# 4                     Healthify Me  Health and Fitness
# 8                 Six pack promise  Health and Fitness
# 12   Yoga-Go: Yoga for weight loss  Health and Fitness
# 17  BodyFast: Intermittent Fasting  Health and Fitness
# 22             StepsApp Predometer  Health and Fitness
# 34  Workout Planner muscle booster  Health and Fitness
# 35                    Club Pilates  Health and Fitness
#
#                                                 label  \
# 4                                          EFFICIENCY
# 8   CRASHES,EFFICIENCY,NON-TECHNICAL/BUSINESS,RESP...
# 12                                         EFFICIENCY
# 17                  NON-TECHNICAL/BUSINESS,EFFICIENCY
# 22                             NON-TECHNICAL/BUSINESS
# 34                                         EFFICIENCY
# 35          EFFICIENCY,NON-TECHNICAL/BUSINESS,CRASHES
#
#                                              Feature  IOS Neg Score  \
# 4                                  complex,confusing       0.191500
# 8   freezes,simple,reminders,great workouts,annoying       0.041875
# 12                                              easy       0.000000
# 17              premium,reminders,easy,Easy,reminder       0.032429
# 22                                             track       0.022250
# 34                                           amazing       0.075000
# 35              convenient,calendar,error,clean,bugs       0.056833
#
#     Android Neg Score  IOS Pos Score  Android Pos Score  IOS Neu Score  \
# 4            0.063000       0.028000           0.073000       0.780500
# 8            0.117875       0.153625           0.160125       0.804625
# 12           0.014000       0.249714           0.154571       0.750286
# 17           0.083857       0.253571           0.175143       0.713905
# 22           0.241000       0.196500           0.216000       0.781250
# 34           0.000000       0.069000           0.590000       0.856000
# 35           0.129000       0.175333           0.170833       0.767833
#
#     Android Neu Score  IOS Compound Score  Android Compound Score
# 4            0.864000           -0.586000                0.038600
# 8            0.722000            0.545650                0.210575
# 12           0.831429            0.863271                0.207857
# 17           0.741000            0.791362                0.241771
# 22           0.542000            0.908450                0.126300
# 34           0.410000           -0.113400                0.877200
# 35           0.700167            0.524700                0.001133

# %%
for app in healthDF["App"]:
    categories = ['Positive Score', 'Negative Score', 'Neutral Score', 'Compund Score']
    categories = [*categories, categories[0]]

    appIOS = [
        healthDF[healthDF["App"] == app]["IOS Pos Score"], 
        healthDF[healthDF["App"] == app]["IOS Neg Score"], 
        healthDF[healthDF["App"] == app]["IOS Neu Score"], 
        healthDF[healthDF["App"] == app]["IOS Compound Score"]
    ]
    appIOS = [*appIOS, appIOS[0]]
    appAndroid = [
        healthDF[healthDF["App"] == app]["Android Pos Score"], 
        healthDF[healthDF["App"] == app]["Android Neg Score"], 
        healthDF[healthDF["App"] == app]["Android Neu Score"], 
        healthDF[healthDF["App"] == app]["Android Compound Score"]
    ]
    appAndroid = [*appAndroid, appAndroid[0]]

    label_loc = np.linspace(start=0, stop=2* np.pi, num=len(appIOS))

    plt.figure(figsize=(8, 8))
    plt.subplot(polar=True)

    plt.plot(label_loc, appIOS, label='IOS')
    plt.plot(label_loc, appAndroid, label='Android')

    plt.title(f"IOS and Android comparison for {app}", size=20)
    lines, labels = plt.thetagrids(np.degrees(label_loc), labels=categories)
    plt.legend()
    plt.show()
#     plt.savefig(f'{app}.png')

# %%
# Difference between ios and android plot
differenceDF = pd.DataFrame()

appNames = resultDF['App'].unique()
for app in appNames:
    negDifference = abs(resultDF[resultDF['App'] == app]["IOS Neg Score"] - resultDF[resultDF['App'] == app]["Android Neg Score"])
#     print(negDifference)
    posDifference = abs(resultDF[resultDF['App'] == app]["IOS Pos Score"] - resultDF[resultDF['App'] == app]["Android Pos Score"])    
    neuDifference = abs(resultDF[resultDF['App'] == app]["IOS Neu Score"] - resultDF[resultDF['App'] == app]["Android Neu Score"])    
    cpdDifference = abs(resultDF[resultDF['App'] == app]["IOS Compound Score"] - resultDF[resultDF['App'] == app]["Android Compound Score"]) 
    dictToAdd = {
        "Category": ",".join(resultDF[resultDF['App'] == app]['Category'].unique()),
        "App": ",".join(resultDF[resultDF['App'] == app]["App"].unique()),
        "Label": ",".join(resultDF[resultDF['App'] == app]["label"].to_numpy()),
        "Feature": ",".join(resultDF[resultDF['App'] == app]["Feature"].to_numpy()),
        "Neg score diff": negDifference.to_numpy()[0],
        "Pos score diff": posDifference.to_numpy()[0],
        "Neu score diff": neuDifference.to_numpy()[0],
        "Compound score diff": cpdDifference.to_numpy()
    }
    differenceDF = pd.concat([differenceDF, pd.DataFrame.from_records([dictToAdd])], ignore_index=True)

# %%
differenceDF.head()
# Out:
#              Category                App  \
# 0         Educational           Lumosity
# 1   Productivity Apps      Spaces by Wix
# 2         Educational  LinkedIn Learning
# 3   Productivity Apps          Wordpress
# 4  Health and Fitness       Healthify Me
#
#                                    Label                 Feature  \
# 0                 NON-TECHNICAL/BUSINESS                 premium
# 1                             EFFICIENCY             easy,simple
# 2  UI,EFFICIENCY,GRAPHICS,RESPONSIVENESS  landscape,UI,easy,slow
# 3                             EFFICIENCY        Easy,easy,simple
# 4                             EFFICIENCY       complex,confusing
#
#    Neg score diff  Pos score diff  Neu score diff    Compound score diff
# 0        0.001000        0.053667        0.052667   [0.6327666666666667]
# 1        0.041667        0.005667        0.047333  [0.39985000000000004]
# 2        0.088143        0.037857        0.050286   [0.7073428571428572]
# 3        0.001357        0.021714        0.023071   [0.4913500000000001]
# 4        0.128500        0.045000        0.083500               [0.6246]

# %%
differenceDF.to_csv("difference.csv", index=False)

# %%
y = appNames
fig = plt.subplots(figsize =(20, 10))
# fig=figure(facecolor='w//hite')
# getting values against each value of y
x = differenceDF["Neg score diff"].to_numpy()
plt.barh(y, x)
 
# setting label of y-axis
plt.ylabel("App names")
 
# setting label of x-axis
plt.xlabel("Difference of negative score")
plt.title("Difference in negative score between ios and android")
plt.savefig("negScoreDif.jpg")
plt.show()

# %%
y = appNames
fig = plt.subplots(figsize =(20, 10))
# fig=figure(facecolor='w//hite')
# getting values against each value of y
x = differenceDF["Pos score diff"].to_numpy()
plt.barh(y, x)
 
# setting label of y-axis
plt.ylabel("App names")
 
# setting label of x-axis
plt.xlabel("Difference of positive score")
plt.title("Difference in positive score between ios and android")
plt.savefig("posScoreDif.jpg")
plt.show()

# %%
# Aggregation of categories
categories = set(resultDF['Category'])
categorySummary = df.Dataframe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-8a058f5e934a> in <module>
#       1 # Aggregation of categories
#       2 categories = set(resultDF['Category'])
# ----> 3 categorySummary = df.Dataframe()
#
# NameError: name 'df' is not defined

# %%
for category in categories:
    currentCat = resultDF[resultDF['Category'] == category]
